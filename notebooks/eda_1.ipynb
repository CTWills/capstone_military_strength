# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
import numpy as np

# %%
# load in initial data from csv
data = pd.read_csv('../data/2024_military_strength_by_country.csv')

# %%
data.describe()
# Out:
#        total_national_populations  total_available_military_manpower  \
# count                1.450000e+02                       1.450000e+02
# mean                 5.405439e+07                       2.558850e+07
# std                  1.694507e+08                       8.547782e+07
# min                  3.608720e+05                       8.300100e+04
# 25%                  5.614571e+06                       2.422763e+06
# 50%                  1.421991e+07                       5.988091e+06
# 75%                  3.923200e+07                       1.733177e+07
# max                  1.413143e+09                       7.630971e+08
#
#        total_manpower_fir_for_military_service  \
# count                             1.450000e+02
# mean                              2.002615e+07
# std                               6.899834e+07
# min                               4.980000e+04
# 25%                               1.908954e+06
# 50%                               4.024948e+06
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 59 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   country                                          145 non-null    object
#  1   total_national_populations                       145 non-null    int64
#  2   total_available_military_manpower                145 non-null    int64
#  3   total_manpower_fir_for_military_service          145 non-null    int64
#  4   total_population_reaching_military_age_annually  145 non-null    int64
#  5   active_service_military_manpower                 145 non-null    int64
#  6   active_service_reserve_components                145 non-null    int64
#  7   active_paramilitary_force_strength               145 non-null    int64
#  8   total_military_aircraft_strength                 145 non-null    int64
# ...

# %%
sns.pairplot(data.iloc[:, :10])
plt.tight_layout()

# %%
sns.pairplot(data.iloc[:, 10:20])
plt.tight_layout()

# %%
sns.pairplot(data.iloc[:, 20:30])
plt.tight_layout()
